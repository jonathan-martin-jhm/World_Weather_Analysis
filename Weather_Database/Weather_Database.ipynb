# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 758

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]       
        city_weather_description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          'Current Description': city_weather_description, 
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | russell
# Processing Record 3 of Set 1 | phultala
# Processing Record 4 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 1 | burgeo
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | yerbogachen
# Processing Record 8 of Set 1 | muros
# Processing Record 9 of Set 1 | college
# Processing Record 10 of Set 1 | bengkulu
# Processing Record 11 of Set 1 | te anau
# Processing Record 12 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | riyadh
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | isangel
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | dingle
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | kaitangata
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | labuan
# Processing Record 32 of Set 1 | tuburan
# Processing Record 33 of Set 1 | eureka
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | maizieres-les-metz
# Processing Record 38 of Set 1 | mecca
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | ballina
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | caernarfon
# Processing Record 43 of Set 1 | ust-nera
# Processing Record 44 of Set 1 | nanakuli
# Processing Record 45 of Set 1 | saint-francois
# Processing Record 46 of Set 1 | baruun-urt
# Processing Record 47 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | thinadhoo
# Processing Record 50 of Set 1 | eyl
# Processing Record 1 of Set 2 | beringovskiy
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | kraskino
# Processing Record 4 of Set 2 | raudeberg
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | sao felix do xingu
# Processing Record 7 of Set 2 | erzin
# Processing Record 8 of Set 2 | wodonga
# Processing Record 9 of Set 2 | kidal
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | vila praia de ancora
# Processing Record 12 of Set 2 | codrington
# Processing Record 13 of Set 2 | baykit
# Processing Record 14 of Set 2 | hay river
# Processing Record 15 of Set 2 | providencia
# Processing Record 16 of Set 2 | mayo
# Processing Record 17 of Set 2 | rovaniemi
# Processing Record 18 of Set 2 | pala
# Processing Record 19 of Set 2 | praia da vitoria
# Processing Record 20 of Set 2 | ust-maya
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | san cristobal
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | santa maria del oro
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | port blair
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | fort nelson
# Processing Record 31 of Set 2 | pervomayskoye
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | bordighera
# Processing Record 34 of Set 2 | bambous virieux
# Processing Record 35 of Set 2 | inhambane
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 2 | kyshtovka
# Processing Record 39 of Set 2 | wanning
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | komsomolets
# Processing Record 43 of Set 2 | katsuura
# Processing Record 44 of Set 2 | narsaq
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | voznesenye
# Processing Record 2 of Set 3 | severo-kurilsk
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | husavik
# Processing Record 5 of Set 3 | ugoofaaru
# Processing Record 6 of Set 3 | lagos
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | panaci
# Processing Record 9 of Set 3 | maceio
# Processing Record 10 of Set 3 | hirara
# Processing Record 11 of Set 3 | kargasok
# Processing Record 12 of Set 3 | poland
# Processing Record 13 of Set 3 | mataura
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | waipawa
# Processing Record 16 of Set 3 | alice springs
# Processing Record 17 of Set 3 | moree
# Processing Record 18 of Set 3 | sao filipe
# Processing Record 19 of Set 3 | dombarovskiy
# Processing Record 20 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 21 of Set 3 | williston
# Processing Record 22 of Set 3 | lingao
# Processing Record 23 of Set 3 | geraldton
# Processing Record 24 of Set 3 | paragominas
# Processing Record 25 of Set 3 | busselton
# Processing Record 26 of Set 3 | vila franca do campo
# Processing Record 27 of Set 3 | leningradskiy
# Processing Record 28 of Set 3 | ano poroia
# Processing Record 29 of Set 3 | kieta
# Processing Record 30 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 31 of Set 3 | hami
# Processing Record 32 of Set 3 | brandfort
# Processing Record 33 of Set 3 | dhidhdhoo
# Processing Record 34 of Set 3 | ecublens
# Processing Record 35 of Set 3 | gorontalo
# Processing Record 36 of Set 3 | nome
# Processing Record 37 of Set 3 | alyangula
# Processing Record 38 of Set 3 | baiyin
# Processing Record 39 of Set 3 | villamontes
# Processing Record 40 of Set 3 | wakkanai
# Processing Record 41 of Set 3 | fairbanks
# Processing Record 42 of Set 3 | pevek
# Processing Record 43 of Set 3 | lazaro cardenas
# Processing Record 44 of Set 3 | port moresby
# Processing Record 45 of Set 3 | iqaluit
# Processing Record 46 of Set 3 | takaka
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | chuy
# Processing Record 50 of Set 3 | luderitz
# Processing Record 1 of Set 4 | port-cartier
# Processing Record 2 of Set 4 | bonavista
# Processing Record 3 of Set 4 | ancud
# Processing Record 4 of Set 4 | kampot
# Processing Record 5 of Set 4 | batsfjord
# Processing Record 6 of Set 4 | atambua
# Processing Record 7 of Set 4 | itarema
# Processing Record 8 of Set 4 | thompson
# Processing Record 9 of Set 4 | cayenne
# Processing Record 10 of Set 4 | charters towers
# Processing Record 11 of Set 4 | hobart
# Processing Record 12 of Set 4 | porto velho
# Processing Record 13 of Set 4 | port elizabeth
# Processing Record 14 of Set 4 | vanimo
# Processing Record 15 of Set 4 | ornskoldsvik
# Processing Record 16 of Set 4 | mount gambier
# Processing Record 17 of Set 4 | gazimurskiy zavod
# Processing Record 18 of Set 4 | innisfail
# Processing Record 19 of Set 4 | alofi
# Processing Record 20 of Set 4 | nybro
# Processing Record 21 of Set 4 | faya
# Processing Record 22 of Set 4 | kodino
# Processing Record 23 of Set 4 | richards bay
# Processing Record 24 of Set 4 | batagay-alyta
# Processing Record 25 of Set 4 | hamilton
# Processing Record 26 of Set 4 | reconquista
# Processing Record 27 of Set 4 | saldanha
# Processing Record 28 of Set 4 | korla
# Processing Record 29 of Set 4 | placer
# Processing Record 30 of Set 4 | castro
# Processing Record 31 of Set 4 | vysokogornyy
# Processing Record 32 of Set 4 | challans
# Processing Record 33 of Set 4 | aklavik
# Processing Record 34 of Set 4 | port macquarie
# Processing Record 35 of Set 4 | shimoda
# Processing Record 36 of Set 4 | ratnagiri
# Processing Record 37 of Set 4 | adrar
# Processing Record 38 of Set 4 | wencheng
# Processing Record 39 of Set 4 | khasan
# Processing Record 40 of Set 4 | shubarshi
# Processing Record 41 of Set 4 | opuwo
# Processing Record 42 of Set 4 | jamestown
# Processing Record 43 of Set 4 | pelym
# Processing Record 44 of Set 4 | flin flon
# Processing Record 45 of Set 4 | mumford
# Processing Record 46 of Set 4 | taveta
# Processing Record 47 of Set 4 | seryshevo
# Processing Record 48 of Set 4 | provideniya
# Processing Record 49 of Set 4 | cidreira
# Processing Record 50 of Set 4 | caravelas
# Processing Record 1 of Set 5 | nyahururu
# Processing Record 2 of Set 5 | raga
# Processing Record 3 of Set 5 | dodola
# Processing Record 4 of Set 5 | talnakh
# Processing Record 5 of Set 5 | mandiana
# Processing Record 6 of Set 5 | yellowknife
# Processing Record 7 of Set 5 | resplendor
# Processing Record 8 of Set 5 | suhut
# Processing Record 9 of Set 5 | broken hill
# Processing Record 10 of Set 5 | faanui
# Processing Record 11 of Set 5 | bathsheba
# Processing Record 12 of Set 5 | alice town
# Processing Record 13 of Set 5 | along
# Processing Record 14 of Set 5 | zyryanka
# Processing Record 15 of Set 5 | catuday
# Processing Record 16 of Set 5 | gopalpur
# Processing Record 17 of Set 5 | anadyr
# Processing Record 18 of Set 5 | acapulco
# Processing Record 19 of Set 5 | elliot lake
# Processing Record 20 of Set 5 | oranjestad
# Processing Record 21 of Set 5 | sabang
# Processing Record 22 of Set 5 | resistencia
# Processing Record 23 of Set 5 | ponta delgada
# Processing Record 24 of Set 5 | komsomolskiy
# Processing Record 25 of Set 5 | broome
# Processing Record 26 of Set 5 | morehead
# Processing Record 27 of Set 5 | kyabe
# Processing Record 28 of Set 5 | mahon
# Processing Record 29 of Set 5 | sterling
# Processing Record 30 of Set 5 | san quintin
# Processing Record 31 of Set 5 | chany
# Processing Record 32 of Set 5 | biltine
# Processing Record 33 of Set 5 | sioux lookout
# Processing Record 34 of Set 5 | keelung
# Processing Record 35 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 5 | sattahip
# Processing Record 38 of Set 5 | lebedinyy
# Processing Record 39 of Set 5 | namatanai
# Processing Record 40 of Set 5 | tazovskiy
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | salalah
# Processing Record 43 of Set 5 | bambanglipuro
# Processing Record 44 of Set 5 | honningsvag
# Processing Record 45 of Set 5 | avera
# Processing Record 46 of Set 5 | lahaina
# Processing Record 47 of Set 5 | nouadhibou
# Processing Record 48 of Set 5 | cabo san lucas
# Processing Record 49 of Set 5 | barrow
# Processing Record 50 of Set 5 | kamenka
# Processing Record 1 of Set 6 | vadso
# Processing Record 2 of Set 6 | zhigansk
# Processing Record 3 of Set 6 | marion
# Processing Record 4 of Set 6 | nizhniy tsasuchey
# Processing Record 5 of Set 6 | katangli
# Processing Record 6 of Set 6 | hokitika
# Processing Record 7 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 8 of Set 6 | hualmay
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | goderich
# Processing Record 11 of Set 6 | whangarei
# Processing Record 12 of Set 6 | havre
# Processing Record 13 of Set 6 | morondava
# Processing Record 14 of Set 6 | ewo
# Processing Record 15 of Set 6 | namibe
# Processing Record 16 of Set 6 | megion
# Processing Record 17 of Set 6 | santo antonio do sudoeste
# Processing Record 18 of Set 6 | sillod
# Processing Record 19 of Set 6 | cochrane
# Processing Record 20 of Set 6 | kahului
# Processing Record 21 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 22 of Set 6 | souillac
# Processing Record 23 of Set 6 | qandahar
# City not found. Skipping...
# Processing Record 24 of Set 6 | dzialdowo
# Processing Record 25 of Set 6 | latung
# Processing Record 26 of Set 6 | praya
# Processing Record 27 of Set 6 | tautira
# Processing Record 28 of Set 6 | indiaroba
# Processing Record 29 of Set 6 | bandarbeyla
# Processing Record 30 of Set 6 | ponta do sol
# Processing Record 31 of Set 6 | naze
# Processing Record 32 of Set 6 | walvis bay
# Processing Record 33 of Set 6 | khani
# Processing Record 34 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 6 | inuvik
# Processing Record 36 of Set 6 | victoria
# Processing Record 37 of Set 6 | rjukan
# Processing Record 38 of Set 6 | saint-louis
# Processing Record 39 of Set 6 | klaksvik
# Processing Record 40 of Set 6 | sitka
# Processing Record 41 of Set 6 | yumen
# Processing Record 42 of Set 6 | mogadishu
# Processing Record 43 of Set 6 | chumikan
# Processing Record 44 of Set 6 | grindavik
# Processing Record 45 of Set 6 | lagoa
# Processing Record 46 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 6 | ahipara
# Processing Record 48 of Set 6 | sukaraja
# Processing Record 49 of Set 6 | ilulissat
# Processing Record 50 of Set 6 | gazanjyk
# Processing Record 1 of Set 7 | qaqortoq
# Processing Record 2 of Set 7 | van
# Processing Record 3 of Set 7 | tilichiki
# Processing Record 4 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 7 | igboho
# Processing Record 6 of Set 7 | rio gallegos
# Processing Record 7 of Set 7 | krasnoselkup
# Processing Record 8 of Set 7 | lucapa
# Processing Record 9 of Set 7 | smithers
# Processing Record 10 of Set 7 | porto novo
# Processing Record 11 of Set 7 | bitung
# Processing Record 12 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 7 | tempio pausania
# Processing Record 14 of Set 7 | akureyri
# Processing Record 15 of Set 7 | puerto penasco
# Processing Record 16 of Set 7 | ucluelet
# Processing Record 17 of Set 7 | tessalit
# Processing Record 18 of Set 7 | fairlie
# Processing Record 19 of Set 7 | kiama
# Processing Record 20 of Set 7 | minab
# Processing Record 21 of Set 7 | arriaga
# Processing Record 22 of Set 7 | marienburg
# Processing Record 23 of Set 7 | nanortalik
# Processing Record 24 of Set 7 | progreso
# Processing Record 25 of Set 7 | salinopolis
# Processing Record 26 of Set 7 | hasaki
# Processing Record 27 of Set 7 | arlit
# Processing Record 28 of Set 7 | zavitinsk
# Processing Record 29 of Set 7 | sarakhs
# Processing Record 30 of Set 7 | derzhavinsk
# Processing Record 31 of Set 7 | atar
# Processing Record 32 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 7 | sao gabriel da cachoeira
# Processing Record 34 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 7 | sonegaon
# Processing Record 36 of Set 7 | fare
# Processing Record 37 of Set 7 | saint-joseph
# Processing Record 38 of Set 7 | harper
# Processing Record 39 of Set 7 | tokur
# Processing Record 40 of Set 7 | chiredzi
# Processing Record 41 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 7 | niles
# Processing Record 43 of Set 7 | safaga
# Processing Record 44 of Set 7 | lavrentiya
# Processing Record 45 of Set 7 | ostrovnoy
# Processing Record 46 of Set 7 | sawai madhopur
# Processing Record 47 of Set 7 | nichinan
# Processing Record 48 of Set 7 | prince rupert
# Processing Record 49 of Set 7 | la ronge
# Processing Record 50 of Set 7 | kalevala
# Processing Record 1 of Set 8 | linchuan
# City not found. Skipping...
# Processing Record 2 of Set 8 | kyzyl-mazhalyk
# Processing Record 3 of Set 8 | ruzhyn
# Processing Record 4 of Set 8 | kalmunai
# Processing Record 5 of Set 8 | lebu
# Processing Record 6 of Set 8 | laranjeiras do sul
# Processing Record 7 of Set 8 | utinga
# Processing Record 8 of Set 8 | palmer
# Processing Record 9 of Set 8 | sechura
# Processing Record 10 of Set 8 | bay saint louis
# Processing Record 11 of Set 8 | scicli
# Processing Record 12 of Set 8 | reitz
# Processing Record 13 of Set 8 | westport
# Processing Record 14 of Set 8 | torbay
# Processing Record 15 of Set 8 | zapolyarnyy
# Processing Record 16 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 17 of Set 8 | trinidad
# Processing Record 18 of Set 8 | constitucion
# Processing Record 19 of Set 8 | pozo colorado
# Processing Record 20 of Set 8 | sakakah
# Processing Record 21 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 8 | bainbridge
# Processing Record 23 of Set 8 | dingzhou
# Processing Record 24 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 8 | springfield
# Processing Record 26 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 8 | kisangani
# Processing Record 28 of Set 8 | mweka
# Processing Record 29 of Set 8 | ossora
# Processing Record 30 of Set 8 | nelson bay
# Processing Record 31 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 32 of Set 8 | kantilo
# Processing Record 33 of Set 8 | ouadda
# Processing Record 34 of Set 8 | umm kaddadah
# Processing Record 35 of Set 8 | belaya gora
# Processing Record 36 of Set 8 | balabac
# Processing Record 37 of Set 8 | zuidhorn
# Processing Record 38 of Set 8 | mar del plata
# Processing Record 39 of Set 8 | shumerlya
# Processing Record 40 of Set 8 | axim
# Processing Record 41 of Set 8 | dubai
# Processing Record 42 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 8 | kabinda
# Processing Record 44 of Set 8 | half moon bay
# Processing Record 45 of Set 8 | rongcheng
# Processing Record 46 of Set 8 | bayanday
# Processing Record 47 of Set 8 | bata
# Processing Record 48 of Set 8 | naryan-mar
# Processing Record 49 of Set 8 | ambilobe
# Processing Record 50 of Set 8 | longyearbyen
# Processing Record 1 of Set 9 | kajaani
# Processing Record 2 of Set 9 | deputatskiy
# Processing Record 3 of Set 9 | peleduy
# Processing Record 4 of Set 9 | san ramon
# Processing Record 5 of Set 9 | ystad
# Processing Record 6 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 9 | pechenga
# Processing Record 8 of Set 9 | waw
# Processing Record 9 of Set 9 | nioro
# Processing Record 10 of Set 9 | ichinohe
# Processing Record 11 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 9 | mujiayingzi
# Processing Record 13 of Set 9 | asfi
# Processing Record 14 of Set 9 | ilawe
# Processing Record 15 of Set 9 | tancanhuitz
# Processing Record 16 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 17 of Set 9 | haines junction
# Processing Record 18 of Set 9 | hobyo
# Processing Record 19 of Set 9 | mount isa
# Processing Record 20 of Set 9 | livingston
# Processing Record 21 of Set 9 | sao joao da barra
# Processing Record 22 of Set 9 | ardakan
# Processing Record 23 of Set 9 | kalundborg
# Processing Record 24 of Set 9 | kolosovka
# Processing Record 25 of Set 9 | rocha
# Processing Record 26 of Set 9 | krupanj
# Processing Record 27 of Set 9 | saint simons
# Processing Record 28 of Set 9 | meulaboh
# Processing Record 29 of Set 9 | tabat
# Processing Record 30 of Set 9 | clyde river
# Processing Record 31 of Set 9 | kysyl-syr
# Processing Record 32 of Set 9 | shingu
# Processing Record 33 of Set 9 | road town
# Processing Record 34 of Set 9 | rokytne
# Processing Record 35 of Set 9 | fortuna
# Processing Record 36 of Set 9 | zhuhai
# Processing Record 37 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 9 | sobolevo
# Processing Record 39 of Set 9 | takoradi
# Processing Record 40 of Set 9 | mpanda
# Processing Record 41 of Set 9 | grand-lahou
# Processing Record 42 of Set 9 | goba
# Processing Record 43 of Set 9 | ploemeur
# Processing Record 44 of Set 9 | marquette
# Processing Record 45 of Set 9 | darlowo
# Processing Record 46 of Set 9 | tuni
# Processing Record 47 of Set 9 | parintins
# Processing Record 48 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 49 of Set 9 | abeche
# Processing Record 50 of Set 9 | pingliang
# Processing Record 1 of Set 10 | celestun
# Processing Record 2 of Set 10 | whitehorse
# Processing Record 3 of Set 10 | chattanooga
# Processing Record 4 of Set 10 | gimbi
# Processing Record 5 of Set 10 | bilma
# Processing Record 6 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 10 | port hardy
# Processing Record 8 of Set 10 | flinders
# Processing Record 9 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 12 of Set 10 | chapais
# Processing Record 13 of Set 10 | lakselv
# Processing Record 14 of Set 10 | coruripe
# Processing Record 15 of Set 10 | male
# Processing Record 16 of Set 10 | ampanihy
# Processing Record 17 of Set 10 | ati
# Processing Record 18 of Set 10 | guaraniacu
# Processing Record 19 of Set 10 | guerrero negro
# Processing Record 20 of Set 10 | ukiah
# Processing Record 21 of Set 10 | dudinka
# Processing Record 22 of Set 10 | coquimbo
# Processing Record 23 of Set 10 | hammonton
# Processing Record 24 of Set 10 | bonthe
# Processing Record 25 of Set 10 | tromso
# Processing Record 26 of Set 10 | nkowakowa
# Processing Record 27 of Set 10 | marystown
# Processing Record 28 of Set 10 | homer
# Processing Record 29 of Set 10 | fairmont
# Processing Record 30 of Set 10 | gigmoto
# Processing Record 31 of Set 10 | touros
# Processing Record 32 of Set 10 | olafsvik
# Processing Record 33 of Set 10 | jalu
# Processing Record 34 of Set 10 | iquitos
# Processing Record 35 of Set 10 | beloha
# Processing Record 36 of Set 10 | gold coast
# Processing Record 37 of Set 10 | bertoua
# Processing Record 38 of Set 10 | bulawayo
# Processing Record 39 of Set 10 | okhotsk
# Processing Record 40 of Set 10 | buala
# Processing Record 41 of Set 10 | acajutla
# Processing Record 42 of Set 10 | shupiyan
# Processing Record 43 of Set 10 | khetri
# Processing Record 44 of Set 10 | gweta
# Processing Record 45 of Set 10 | loandjili
# Processing Record 46 of Set 10 | waingapu
# Processing Record 47 of Set 10 | shahrud
# Processing Record 48 of Set 10 | samfya
# Processing Record 49 of Set 10 | snejbjerg
# Processing Record 50 of Set 10 | port hedland
# Processing Record 1 of Set 11 | tabou
# Processing Record 2 of Set 11 | elban
# Processing Record 3 of Set 11 | velka bites
# Processing Record 4 of Set 11 | soavinandriana
# Processing Record 5 of Set 11 | houma
# Processing Record 6 of Set 11 | asau
# Processing Record 7 of Set 11 | sorong
# Processing Record 8 of Set 11 | pandan
# Processing Record 9 of Set 11 | santa clara
# Processing Record 10 of Set 11 | morant bay
# Processing Record 11 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 12 of Set 11 | paamiut
# Processing Record 13 of Set 11 | quatre cocos
# Processing Record 14 of Set 11 | anloga
# Processing Record 15 of Set 11 | frontera
# Processing Record 16 of Set 11 | klyuchi
# Processing Record 17 of Set 11 | ingham
# Processing Record 18 of Set 11 | gaimersheim
# Processing Record 19 of Set 11 | toktogul
# Processing Record 20 of Set 11 | sola
# Processing Record 21 of Set 11 | hambantota
# Processing Record 22 of Set 11 | malanje
# Processing Record 23 of Set 11 | saskylakh
# Processing Record 24 of Set 11 | kirakira
# Processing Record 25 of Set 11 | stornoway
# Processing Record 26 of Set 11 | lerwick
# Processing Record 27 of Set 11 | suarez
# Processing Record 28 of Set 11 | inyonga
# Processing Record 29 of Set 11 | munai
# Processing Record 30 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 11 | dengzhou
# Processing Record 32 of Set 11 | chahuites
# Processing Record 33 of Set 11 | poum
# Processing Record 34 of Set 11 | cockburn town
# Processing Record 35 of Set 11 | altay
# Processing Record 36 of Set 11 | itaituba
# Processing Record 37 of Set 11 | gemlik
# Processing Record 38 of Set 11 | estelle
# Processing Record 39 of Set 11 | henties bay
# Processing Record 40 of Set 11 | ape
# Processing Record 41 of Set 11 | salekhard
# Processing Record 42 of Set 11 | egvekinot
# Processing Record 43 of Set 11 | diego de almagro
# Processing Record 44 of Set 11 | huanren
# Processing Record 45 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 46 of Set 11 | kroya
# Processing Record 47 of Set 11 | arusha
# Processing Record 48 of Set 11 | aktau
# Processing Record 49 of Set 11 | firozpur
# Processing Record 50 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 12 | sohag
# Processing Record 2 of Set 12 | shangzhi
# Processing Record 3 of Set 12 | george town
# Processing Record 4 of Set 12 | kudahuvadhoo
# Processing Record 5 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 12 | kyabram
# Processing Record 7 of Set 12 | berlevag
# Processing Record 8 of Set 12 | sinnamary
# Processing Record 9 of Set 12 | mitsukaido
# Processing Record 10 of Set 12 | kutum
# Processing Record 11 of Set 12 | evensk
# Processing Record 12 of Set 12 | lowestoft
# Processing Record 13 of Set 12 | maragogi
# Processing Record 14 of Set 12 | banda aceh
# Processing Record 15 of Set 12 | yichun
# Processing Record 16 of Set 12 | havoysund
# Processing Record 17 of Set 12 | jawa
# Processing Record 18 of Set 12 | chifeng
# Processing Record 19 of Set 12 | muhos
# Processing Record 20 of Set 12 | bairiki
# Processing Record 21 of Set 12 | ierapetra
# Processing Record 22 of Set 12 | valentin gomez farias
# Processing Record 23 of Set 12 | tarangnan
# Processing Record 24 of Set 12 | mapiripan
# Processing Record 25 of Set 12 | buarcos
# Processing Record 26 of Set 12 | cuiluan
# Processing Record 27 of Set 12 | lasa
# Processing Record 28 of Set 12 | port-gentil
# Processing Record 29 of Set 12 | springbok
# Processing Record 30 of Set 12 | kilindoni
# Processing Record 31 of Set 12 | sisimiut
# Processing Record 32 of Set 12 | puerto madryn
# Processing Record 33 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 12 | teguldet
# Processing Record 35 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 36 of Set 12 | veshkayma
# Processing Record 37 of Set 12 | camocim
# Processing Record 38 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 12 | jenbach
# Processing Record 40 of Set 12 | grand gaube
# Processing Record 41 of Set 12 | seoul
# Processing Record 42 of Set 12 | lorengau
# Processing Record 43 of Set 12 | cozumel
# Processing Record 44 of Set 12 | solnechnyy
# Processing Record 45 of Set 12 | ternate
# Processing Record 46 of Set 12 | morros
# Processing Record 47 of Set 12 | prado
# Processing Record 48 of Set 12 | acarau
# Processing Record 49 of Set 12 | taoudenni
# Processing Record 50 of Set 12 | bethel
# Processing Record 1 of Set 13 | chisinau
# Processing Record 2 of Set 13 | petropavl
# Processing Record 3 of Set 13 | iwanai
# Processing Record 4 of Set 13 | pho chai
# Processing Record 5 of Set 13 | tambopata
# Processing Record 6 of Set 13 | vao
# Processing Record 7 of Set 13 | romny
# Processing Record 8 of Set 13 | lishui
# Processing Record 9 of Set 13 | mackay
# Processing Record 10 of Set 13 | makakilo city
# Processing Record 11 of Set 13 | terrace
# Processing Record 12 of Set 13 | rostovka
# Processing Record 13 of Set 13 | guarabira
# Processing Record 14 of Set 13 | monrovia
# Processing Record 15 of Set 13 | valley
# Processing Record 16 of Set 13 | panzhihua
# Processing Record 17 of Set 13 | sao borja
# Processing Record 18 of Set 13 | santa maria da vitoria
# Processing Record 19 of Set 13 | robertsport
# Processing Record 20 of Set 13 | halifax
# Processing Record 21 of Set 13 | gilroy
# Processing Record 22 of Set 13 | abaetetuba
# Processing Record 23 of Set 13 | arman
# Processing Record 24 of Set 13 | dovers
# Processing Record 25 of Set 13 | chipinge
# Processing Record 26 of Set 13 | kruisfontein
# Processing Record 27 of Set 13 | olinda
# Processing Record 28 of Set 13 | datong
# Processing Record 29 of Set 13 | gornopravdinsk
# Processing Record 30 of Set 13 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 31 of Set 13 | waldheim
# Processing Record 32 of Set 13 | kantunilkin
# Processing Record 33 of Set 13 | cedar city
# Processing Record 34 of Set 13 | morden
# Processing Record 35 of Set 13 | saiha
# Processing Record 36 of Set 13 | turbat
# Processing Record 37 of Set 13 | lamu
# Processing Record 38 of Set 13 | yangmei
# Processing Record 39 of Set 13 | baker city
# Processing Record 40 of Set 13 | bubaque
# Processing Record 41 of Set 13 | zeya
# Processing Record 42 of Set 13 | tongchuan
# Processing Record 43 of Set 13 | taltal
# Processing Record 44 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 45 of Set 13 | merauke
# Processing Record 46 of Set 13 | kita
# Processing Record 47 of Set 13 | abu dhabi
# Processing Record 48 of Set 13 | eganville
# Processing Record 49 of Set 13 | margate
# Processing Record 50 of Set 13 | surab
# Processing Record 1 of Set 14 | asyut
# Processing Record 2 of Set 14 | vavozh
# Processing Record 3 of Set 14 | blackfoot
# Processing Record 4 of Set 14 | ozernovskiy
# Processing Record 5 of Set 14 | tibu
# Processing Record 6 of Set 14 | cabedelo
# Processing Record 7 of Set 14 | zarubino
# Processing Record 8 of Set 14 | slave lake
# Processing Record 9 of Set 14 | general roca
# Processing Record 10 of Set 14 | black river
# Processing Record 11 of Set 14 | coihaique
# Processing Record 12 of Set 14 | paita
# Processing Record 13 of Set 14 | genhe
# Processing Record 14 of Set 14 | aripuana
# Processing Record 15 of Set 14 | ha noi
# Processing Record 16 of Set 14 | sandviken
# Processing Record 17 of Set 14 | nishihara
# Processing Record 18 of Set 14 | shahreza
# Processing Record 19 of Set 14 | villa del rosario
# Processing Record 20 of Set 14 | karakose
# City not found. Skipping...
# Processing Record 21 of Set 14 | santa rosa
# Processing Record 22 of Set 14 | maloy
# Processing Record 23 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 14 | banyo
# Processing Record 25 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 27 of Set 14 | illapel
# Processing Record 28 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 29 of Set 14 | gazli
# Processing Record 30 of Set 14 | yulara
# Processing Record 31 of Set 14 | hornepayne
# Processing Record 32 of Set 14 | carutapera
# Processing Record 33 of Set 14 | tura
# Processing Record 34 of Set 14 | kasane
# Processing Record 35 of Set 14 | yantal
# Processing Record 36 of Set 14 | kango
# Processing Record 37 of Set 14 | satapuala
# Processing Record 38 of Set 14 | bodden town
# Processing Record 39 of Set 14 | mitsamiouli
# Processing Record 40 of Set 14 | marquard
# Processing Record 41 of Set 14 | seymchan
# Processing Record 42 of Set 14 | penzance
# Processing Record 43 of Set 14 | abu zabad
# Processing Record 44 of Set 14 | znamenskoye
# Processing Record 45 of Set 14 | putina
# Processing Record 46 of Set 14 | homa bay
# Processing Record 47 of Set 14 | port keats
# Processing Record 48 of Set 14 | urengoy
# Processing Record 49 of Set 14 | novo aripuana
# Processing Record 50 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 1 of Set 15 | baijiantan
# Processing Record 2 of Set 15 | rioja
# Processing Record 3 of Set 15 | vardo
# Processing Record 4 of Set 15 | puerto suarez
# Processing Record 5 of Set 15 | bogatic
# Processing Record 6 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 15 | karratha
# Processing Record 8 of Set 15 | vikhorevka
# Processing Record 9 of Set 15 | escanaba
# Processing Record 10 of Set 15 | lexington
# Processing Record 11 of Set 15 | juazeirinho
# Processing Record 12 of Set 15 | borovoy
# Processing Record 13 of Set 15 | portland
# Processing Record 14 of Set 15 | rahatgarh
# Processing Record 15 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 15 | kyra
# Processing Record 17 of Set 15 | noumea
# Processing Record 18 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 15 | arenzano
# Processing Record 20 of Set 15 | colares
# Processing Record 21 of Set 15 | tigil
# Processing Record 22 of Set 15 | bitkine
# Processing Record 23 of Set 15 | hirado
# Processing Record 24 of Set 15 | portobelo
# Processing Record 25 of Set 15 | labuhan
# Processing Record 26 of Set 15 | charlestown
# Processing Record 27 of Set 15 | guajara-mirim
# City not found. Skipping...
# Processing Record 28 of Set 15 | kapoeta
# Processing Record 29 of Set 15 | fuling
# Processing Record 30 of Set 15 | najran
# Processing Record 31 of Set 15 | viedma
# Processing Record 32 of Set 15 | malpura
# Processing Record 33 of Set 15 | maryborough
# Processing Record 34 of Set 15 | craig
# Processing Record 35 of Set 15 | sistranda
# Processing Record 36 of Set 15 | maua
# Processing Record 37 of Set 15 | hervey bay
# Processing Record 38 of Set 15 | shaunavon
# Processing Record 39 of Set 15 | gurupa
# Processing Record 40 of Set 15 | hovd
# Processing Record 41 of Set 15 | renqiu
# Processing Record 42 of Set 15 | tateyama
# Processing Record 43 of Set 15 | jumla
# Processing Record 44 of Set 15 | aguimes
# Processing Record 45 of Set 15 | atka
# City not found. Skipping...
# Processing Record 46 of Set 15 | srednekolymsk
# Processing Record 47 of Set 15 | rudnogorsk
# Processing Record 48 of Set 15 | rabwah
# City not found. Skipping...
# Processing Record 49 of Set 15 | muravlenko
# Processing Record 50 of Set 15 | mpika
# Processing Record 1 of Set 16 | sri aman
# Processing Record 2 of Set 16 | barcelona
# Processing Record 3 of Set 16 | sawtell
# Processing Record 4 of Set 16 | bukit bakri
# City not found. Skipping...
# Processing Record 5 of Set 16 | abu jubayhah
# City not found. Skipping...
# Processing Record 6 of Set 16 | aykhal
# Processing Record 7 of Set 16 | kailua
# Processing Record 8 of Set 16 | yangambi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 695

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df = city_data_df.drop(columns = ['Date'])
city_data_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18864\1764868688.py in <module>
#       1 # Display sample data
# ----> 2 city_data_df = city_data_df.drop(columns = ['Date'])
#       3 city_data_df.head(10)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Date'] not found in axis"

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus      ZA -34.4187   19.2345     57.79        70          91
# 1       Russell      US  32.3502  -85.1999     58.28        44           0
# 2      Phultala      BD  22.7000   89.5167     63.77        59           0
# 3        Burgeo      CA  47.6167  -57.6152     35.47        67          99
# 4  San Patricio      US  28.0170  -97.5169     51.67        63         100
# 5   Yerbogachen      RU  61.2767  108.0108      7.97        96         100
# 6         Muros      ES  42.7762   -9.0603     63.14        86         100
# 7       College      US  64.8569 -147.8028     13.59        83          20
# 8      Bengkulu      ID  -3.8004  102.2655     75.24        97         100
# 9       Te Anau      NZ -45.4167  167.7167     55.94        90         100
#
#    Wind Speed Current Description
# 0        3.69     overcast clouds
# 1       12.66           clear sky
# 2        6.02           clear sky
# 3        5.01     overcast clouds
# 4       11.61     overcast clouds
# 5        1.45     overcast clouds
# 6       16.84     overcast clouds
# 7        0.00          few clouds
# 8       15.66          light rain
# 9        1.16     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
